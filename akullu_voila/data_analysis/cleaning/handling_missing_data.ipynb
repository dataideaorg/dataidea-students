# %%
import pandas as pd

# %%
data = pd.read_csv('../datasets/titanic3.csv')

# %%
data.shape
# Out:
# (1310, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   float64
#  1   survived   1309 non-null   float64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   float64
#  6   parch      1309 non-null   float64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(7), object(7)
# memory usage: 143.4+ KB

# %%
data.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
def dropMissingData(data_frame, column_name):
    data_frame_with_missing_data = data_frame[data_frame[column_name].isna()]
    indexes = data_frame_with_missing_data.index
    rows_to_drop = indexes.values
    data_frame2 = data_frame.drop(rows_to_drop)
    return data_frame2

# %%
data2 = dropMissingData(data, 'pclass')

# %%
data2.isna().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
data3 = data2.drop(columns=['body', 'cabin'])

# %%
data3[data3.fare.isna()]
# Out:
#       pclass  survived                name   sex   age  sibsp  parch ticket  \
# 1225     3.0       0.0  Storey, Mr. Thomas  male  60.5    0.0    0.0   3701
#
#       fare embarked boat home.dest
# 1225   NaN        S  NaN       NaN

# %%
data3['fare'] = data3['fare'].fillna(data3.fare.mean())

# %%
data3[data3.embarked.isna()]
# Out:
#      pclass  survived                                       name     sex  \
# 168     1.0       1.0                        Icard, Miss. Amelie  female
# 284     1.0       1.0  Stone, Mrs. George Nelson (Martha Evelyn)  female
#
#       age  sibsp  parch  ticket  fare embarked boat       home.dest
# 168  38.0    0.0    0.0  113572  80.0      NaN    6             NaN
# 284  62.0    0.0    0.0  113572  80.0      NaN    6  Cincinatti, OH

# %%
# return the distribution of values among categories in a column
data3.embarked.value_counts()
# Out:
# embarked
# S    914
# C    270
# Q    123
# Name: count, dtype: int64

# %%
data3['embarked'] = data3['embarked'].fillna(value='S')

# %%
boat_na = data3[data3.boat.isna()]

# %%
boat_na[boat_na.survived == 1.0]
# Out:
#       pclass  survived                                               name  \
# 192      1.0       1.0                               Lurette, Miss. Elise
# 358      2.0       1.0                           Bystrom, Mrs. (Karolina)
# 395      2.0       1.0                                Doling, Miss. Elsie
# 396      2.0       1.0               Doling, Mrs. John T (Ada Julia Bone)
# 458      2.0       1.0                                Ilett, Miss. Bertha
# 489      2.0       1.0  Louch, Mrs. Charles Alexander (Alice Adelaide ...
# 513      2.0       1.0                Nasser, Mrs. Nicholas (Adele Achem)
# 545      2.0       1.0        Renouf, Mrs. Peter Henry (Lillian Jefferys)
# 572      2.0       1.0                   Trout, Mrs. William H (Jessie L)
# 656      3.0       1.0  Backstrom, Mrs. Karl Alfred (Maria Mathilda Gu...
# 780      3.0       1.0                              Drapkin, Miss. Jennie
# 860      3.0       1.0                             Heikkinen, Miss. Laina
# 870      3.0       1.0                             Honkanen, Miss. Eliina
# 926      3.0       1.0                                  Kennedy, Mr. John
# 1000     3.0       1.0                       McCormack, Mr. Thomas Joseph
# 1007     3.0       1.0                        McGowan, Miss. Anna "Annie"
# 1037     3.0       1.0                     Moussa, Mrs. (Mantoura Boulos)
# 1071     3.0       1.0    O'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)
# 1078     3.0       1.0                      O'Dwyer, Miss. Ellen "Nellie"
# 1094     3.0       1.0                                   Osman, Mrs. Mara
# 1198     3.0       1.0                         Shine, Miss. Ellen Natalia
# 1290     3.0       1.0                   Wilkes, Mrs. James (Ellen Needs)
# 1300     3.0       1.0            Yasbeck, Mrs. Antoni (Selini Alexander)
#
#          sex   age  sibsp  parch            ticket      fare embarked boat  \
# 192   female  58.0    0.0    0.0          PC 17569  146.5208        C  NaN
# 358   female  42.0    0.0    0.0            236852   13.0000        S  NaN
# 395   female  18.0    0.0    1.0            231919   23.0000        S  NaN
# 396   female  34.0    0.0    1.0            231919   23.0000        S  NaN
# 458   female  17.0    0.0    0.0        SO/C 14885   10.5000        S  NaN
# 489   female  42.0    1.0    0.0        SC/AH 3085   26.0000        S  NaN
# 513   female  14.0    1.0    0.0            237736   30.0708        C  NaN
# 545   female  30.0    3.0    0.0             31027   21.0000        S  NaN
# 572   female  28.0    0.0    0.0            240929   12.6500        S  NaN
# 656   female  33.0    3.0    0.0           3101278   15.8500        S  NaN
# 780   female  23.0    0.0    0.0   SOTON/OQ 392083    8.0500        S  NaN
# 860   female  26.0    0.0    0.0  STON/O2. 3101282    7.9250        S  NaN
# 870   female  27.0    0.0    0.0  STON/O2. 3101283    7.9250        S  NaN
# 926     male   NaN    0.0    0.0            368783    7.7500        Q  NaN
# 1000    male   NaN    0.0    0.0            367228    7.7500        Q  NaN
# 1007  female  15.0    0.0    0.0            330923    8.0292        Q  NaN
# 1037  female   NaN    0.0    0.0              2626    7.2292        C  NaN
# 1071  female   NaN    1.0    0.0            370365   15.5000        Q  NaN
# 1078  female   NaN    0.0    0.0            330959    7.8792        Q  NaN
# 1094  female  31.0    0.0    0.0            349244    8.6833        S  NaN
# 1198  female   NaN    0.0    0.0            330968    7.7792        Q  NaN
# 1290  female  47.0    1.0    0.0            363272    7.0000        S  NaN
# 1300  female  15.0    1.0    0.0              2659   14.4542        C  NaN
#
#                                 home.dest
# 192                                   NaN
# 358                          New York, NY
# 395                           Southampton
# 396                           Southampton
# 458                              Guernsey
# 489           Weston-Super-Mare, Somerset
# 513                          New York, NY
# 545                         Elizabeth, NJ
# 572                          Columbus, OH
# 656   Ruotsinphytaa, Finland New York, NY
# 780                   London New York, NY
# 860                                   NaN
# 870                                   NaN
# 926                                   NaN
# 1000                                  NaN
# 1007                                  NaN
# 1037                                  NaN
# 1071                                  NaN
# 1078                                  NaN
# 1094                                  NaN
# 1198                                  NaN
# 1290                                  NaN
# 1300                                  NaN

# %%
data3.drop(columns=['boat', 'home.dest'], inplace=True)

# %%
data3[data3.age.isna()]
# Out:
#       pclass  survived                                               name  \
# 37       1.0       1.0      Bradley, Mr. George ("George Arthur Brayton")
# 40       1.0       0.0                          Brewe, Dr. Arthur Jackson
# 46       1.0       0.0                              Cairns, Mr. Alexander
# 59       1.0       1.0  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
# 69       1.0       1.0             Chibnall, Mrs. (Edith Martha Bowerman)
# ...      ...       ...                                                ...
# 1293     3.0       0.0                  Williams, Mr. Howard Hugh "Harry"
# 1297     3.0       0.0                             Wiseman, Mr. Phillippe
# 1302     3.0       0.0                                  Yousif, Mr. Wazli
# 1303     3.0       0.0                              Yousseff, Mr. Gerious
# 1305     3.0       0.0                              Zabour, Miss. Thamine
#
#          sex  age  sibsp  parch      ticket     fare embarked
# 37      male  NaN    0.0    0.0      111427  26.5500        S
# 40      male  NaN    0.0    0.0      112379  39.6000        C
# 46      male  NaN    0.0    0.0      113798  31.0000        S
# 59    female  NaN    0.0    0.0       17770  27.7208        C
# 69    female  NaN    0.0    1.0      113505  55.0000        S
# ...      ...  ...    ...    ...         ...      ...      ...
# 1293    male  NaN    0.0    0.0    A/5 2466   8.0500        S
# 1297    male  NaN    0.0    0.0  A/4. 34244   7.2500        S
# 1302    male  NaN    0.0    0.0        2647   7.2250        C
# 1303    male  NaN    0.0    0.0        2627  14.4583        C
# 1305  female  NaN    1.0    0.0        2665  14.4542        C
#
# [262 rows x 10 columns]

# %%
def replaceAge(names_list, ages_list):
    for count in range(len(name_list)):
        data3.loc[data3['name'] == names_list[count], 'age'] = new_age[count]

# %%
replaceAge(names_list=['Baumann, Mr. John D'], ages_list=[60])

# %%
data3[data3.name == 'Baumann, Mr. John D']
# Out:
#     pclass  survived                 name   sex   age  sibsp  parch    ticket  \
# 15     1.0       0.0  Baumann, Mr. John D  male  60.0    0.0    0.0  PC 17318
#
#       fare embarked
# 15  25.925        S
