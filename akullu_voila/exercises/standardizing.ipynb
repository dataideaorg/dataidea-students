# %%
# (x-mean)/standard_deviation
import numpy as np

def standardizer(values):
    mean_value = np.mean(values)
    standard_div = np.std(values)
    
    standardized = [(value-mean_value)/standard_div for value in values]
    return standardized

# %%
ages = [15,20,25,30,35,40,45,50]

# age = np.mean(ages)

standard_div = np.std(ages)

# print(age)
# print(standard_div)

standardizer(values=ages)
# Out:
# 1.0

# %%
import pandas as pd
data = pd.read_excel(io='/home/jumashafara/work/dataidea/students/voila/data_analysis/demo.xlsx')

# %%
data1 = data.dropna()
data1
# Out:
#      Age Gender Marital Status  Address  Income  Income Category  Job Category
# 0     55      f              1       12      72                3             3
# 1     56      m              0       29     153                4             3
# 2     28      f      no answer        9      28                2             1
# 3     24      m              1        4      26                2             1
# 4     25      m      no answer        2      23                1             2
# ..   ...    ...            ...      ...     ...              ...           ...
# 195   45      f              0        3      86                4             3
# 196   23      f              1        2      27                2             1
# 197   66      f              1       32      11                1             2
# 198   49      m              0        4      30                2             1
# 199   45      m              0        1     147                4             3
#
# [200 rows x 7 columns]

# %%
data2 = data1.sample(n=25)
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 58 to 11
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              25 non-null     int64
#  1   Gender           25 non-null     object
#  2   Marital Status   25 non-null     object
#  3   Address          25 non-null     int64
#  4   Income           25 non-null     int64
#  5   Income Category  25 non-null     int64
#  6   Job Category     25 non-null     int64
# dtypes: int64(5), object(2)
# memory usage: 1.6+ KB

# %%
data2['standardized_age'] = standardizer(values=data2.Age)
data2
# Out:
#      Age Gender Marital Status  Address  Income  Income Category  \
# 58    53      f              0       10      52                3
# 15    35      m              0        8      70                3
# 165   47      f              0       22     232                4
# 23    65      m              1       17      42                2
# 60    23      m              1        1      15                1
# 77    39      m              0        2      43                2
# 80    38      m              0        7      42                2
# 56    56      f              1       12      50                3
# 184   64      f              0       40      16                1
# 82    54      m              0        1      28                2
# 28    41      f              1       19      70                3
# 44    22      f              0        0      45                2
# 119   53      f              0       34     136                4
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(x=data2['Age'],y=data2['Income'],c='y',marker='*')
plt.title('Income against age')
plt.xlabel('Age')
plt.ylabel('Income')
plt.gcf() # get current figure
plt.savefig(fname='graph3.png')
